# %%
# Gregor von Laszewski laszewski@gmail.com

# %%
# %matplotlib inline
import pandas.errors

from cloudmesh.common.util import readfile
from glob import glob
from cloudmesh.common.Shell import Shell
from cloudmesh.common.FlatDict import FlatDict
import sys
from io import StringIO
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import json
import traceback
from pprint import pprint
import ast
import os

# %%
# dirname = "data/project.2/*/*.out"
print(os.getcwd())
dirname = "../results/rivanna/train/project/*/*.out"
files = glob(dirname)
pprint (files)
print (len(files))
# Out:
# /Users/grey/Desktop/github/cloudmesh-community/cm/5/osmi/target/analysis
# ['../results/rivanna/train/project/model_small_lstm_directive_rtx2080_repeat_6/osmi-rtx2080_small_lstm-6-thf2bn-56449405.out',
#  '../results/rivanna/train/project/model_small_lstm_directive_rtx2080_repeat_1/osmi-rtx2080_small_lstm-1-thf2bn-56449400.out',
#  '../results/rivanna/train/project/model_small_lstm_directive_rtx2080_repeat_8/osmi-rtx2080_small_lstm-8-thf2bn-56449407.out',
#  '../results/rivanna/train/project/model_large_tcnn_directive_rtx3090_repeat_10/osmi-rtx3090_large_tcnn-10-thf2bn-56449559.out',
#  '../results/rivanna/train/project/model_medium_cnn_directive_rtx2080_repeat_9/osmi-rtx2080_medium_cnn-9-thf2bn-56449478.out',
#  '../results/rivanna/train/project/model_small_lstm_directive_a6000_repeat_7/osmi-a6000_small_lstm-7-thf2bn-56449436.out',
#  '../results/rivanna/train/project/model_large_tcnn_directive_v100_repeat_9/osmi-v100_large_tcnn-9-thf2bn-56449538.out',
#  '../results/rivanna/train/project/model_medium_cnn_directive_rtx2080_repeat_7/osmi-rtx2080_medium_cnn-7-thf2bn-56449476.out',
#  '../results/rivanna/train/project/model_large_tcnn_directive_v100_repeat_7/osmi-v100_large_tcnn-7-thf2bn-56449536.out',
#  '../results/rivanna/train/project/model_small_lstm_directive_a6000_repeat_9/osmi-a6000_small_lstm-9-thf2bn-56449438.out',
#  '../results/rivanna/train/project/model_small_lstm_directive_rtx2080_repeat_9/osmi-rtx2080_small_lstm-9-thf2bn-56449408.out',
#  '../results/rivanna/train/project/model_small_lstm_directive_rtx2080_repeat_7/osmi-rtx2080_small_lstm-7-thf2bn-56449406.out',
#  '../results/rivanna/train/project/model_medium_cnn_directive_rtx2080_repeat_1/osmi-rtx2080_medium_cnn-1-thf2bn-56449470.out',
#  '../results/rivanna/train/project/model_small_lstm_directive_a6000_repeat_8/osmi-a6000_small_lstm-8-thf2bn-56449437.out',
#  '../results/rivanna/train/project/model_large_tcnn_directive_v100_repeat_6/osmi-v100_large_tcnn-6-thf2bn-56449535.out',
#  '../results/rivanna/train/project/model_medium_cnn_directive_rtx2080_repeat_6/osmi-rtx2080_medium_cnn-6-thf2bn-56449475.out',
#  '../results/rivanna/train/project/model_large_tcnn_directive_v100_repeat_1/osmi-v100_large_tcnn-1-thf2bn-56449530.out',
#  '../results/rivanna/train/project/model_large_tcnn_directive_v100_repeat_8/osmi-v100_large_tcnn-8-thf2bn-56449537.out',
#  '../results/rivanna/train/project/model_small_lstm_directive_a6000_repeat_6/osmi-a6000_small_lstm-6-thf2bn-56449435.out',
#  '../results/rivanna/train/project/model_small_lstm_directive_a6000_repeat_1/osmi-a6000_small_lstm-1-thf2bn-56449430.out',
#  '../results/rivanna/train/project/model_medium_cnn_directive_rtx2080_repeat_8/osmi-rtx2080_medium_cnn-8-thf2bn-56449477.out',
#  '../results/rivanna/train/project/model_large_tcnn_directive_rtx2080_repeat_8/osmi-rtx2080_large_tcnn-8-thf2bn-56449547.out',
#  '../results/rivanna/train/project/model_large_tcnn_directive_a100-dgx_repeat_8/osmi-a100-dgx_large_tcnn-8-thf2bn-56449527.out',
#  '../results/rivanna/train/project/model_large_tcnn_directive_a100_repeat_4/osmi-a100_large_tcnn-4-thf2bn-56449513.out',
#  '../results/rivanna/train/project/model_large_tcnn_directive_rtx2080_repeat_6/osmi-rtx2080_large_tcnn-6-thf2bn-56449545.out',
#  '../results/rivanna/train/project/model_large_tcnn_directive_a100-dgx_repeat_1/osmi-a100-dgx_large_tcnn-1-thf2bn-56449520.out',
#  '../results/rivanna/train/project/model_large_tcnn_directive_a100_repeat_3/osmi-a100_large_tcnn-3-thf2bn-56449512.out',
#  '../results/rivanna/train/project/model_large_tcnn_directive_a100-dgx_repeat_10/osmi-a100-dgx_large_tcnn-10-thf2bn-56449529.out',
#  '../results/rivanna/train/project/model_large_tcnn_directive_a100-dgx_repeat_6/osmi-a100-dgx_large_tcnn-6-thf2bn-56449525.out',
#  '../results/rivanna/train/project/model_large_tcnn_directive_rtx2080_repeat_1/osmi-rtx2080_large_tcnn-1-thf2bn-56449540.out',
#  '../results/rivanna/train/project/model_large_tcnn_directive_a100-pod_repeat_7/osmi-a100-pod_large_tcnn-7-thf2bn-56449566.out',
#  '../results/rivanna/train/project/model_large_tcnn_directive_a
out',
#  '../results/rivanna/train/project/model_small_lstm_directive_a100_repeat_4/osmi-a100_small_lstm-4-thf2bn-56449370.out',
#  '../results/rivanna/train/project/model_small_lstm_directive_a100-pod_repeat_7/osmi-a100-pod_small_lstm-7-thf2bn-56449426.out',
#  '../results/rivanna/train/project/model_small_lstm_directive_rtx3090_repeat_9/osmi-rtx3090_small_lstm-9-thf2bn-56449418.out',
#  '../results/rivanna/train/project/model_small_lstm_directive_a100-dgx_repeat_9/osmi-a100-dgx_small_lstm-9-thf2bn-56449385.out',
#  '../results/rivanna/train/project/model_large_tcnn_directive_a6000_repeat_5/osmi-a6000_large_tcnn-5-thf2bn-56449574.out',
#  '../results/rivanna/train/project/model_large_tcnn_directive_a6000_repeat_2/osmi-a6000_large_tcnn-2-thf2bn-56449571.out',
#  '../results/rivanna/train/project/model_medium_cnn_directive_rtx3090_repeat_7/osmi-rtx3090_medium_cnn-7-thf2bn-56449486.out',
#  '../results/rivanna/train/project/model_medium_cnn_directive_a6000_repeat_3/osmi-a6000_medium_cnn-3-thf2bn-56449502.out',
#  '../results/rivanna/train/project/model_medium_cnn_directive_v100_repeat_5/osmi-v100_medium_cnn-5-thf2bn-56449464.out',
#  '../results/rivanna/train/project/model_small_lstm_directive_a100-dgx_repeat_7/osmi-a100-dgx_small_lstm-7-thf2bn-56449383.out',
#  '../results/rivanna/train/project/model_medium_cnn_directive_v100_repeat_2/osmi-v100_medium_cnn-2-thf2bn-56449461.out',
#  '../results/rivanna/train/project/model_medium_cnn_directive_rtx3090_repeat_9/osmi-rtx3090_medium_cnn-9-thf2bn-56449488.out',
#  '../results/rivanna/train/project/model_medium_cnn_directive_a6000_repeat_4/osmi-a6000_medium_cnn-4-thf2bn-56449503.out',
#  '../results/rivanna/train/project/model_medium_cnn_directive_a100-dgx_repeat_10/osmi-a100-dgx_medium_cnn-10-thf2bn-56449459.out',
#  '../results/rivanna/train/project/model_small_lstm_directive_a6000_repeat_10/osmi-a6000_small_lstm-10-thf2bn-56449439.out',
#  '../results/rivanna/train/project/model_small_lstm_directive_a100-pod_repeat_1/osmi-a100-pod_small_lstm-1-thf2bn-56449420.out',
#  '../results/rivanna/train/project/model_medium_cnn_directive_rtx2080_repeat_10/osmi-rtx2080_medium_cnn-10-thf2bn-56449479.out',
#  '../results/rivanna/train/project/model_small_lstm_directive_a100-pod_repeat_6/osmi-a100-pod_small_lstm-6-thf2bn-56449425.out',
#  '../results/rivanna/train/project/model_small_lstm_directive_rtx3090_repeat_8/osmi-rtx3090_small_lstm-8-thf2bn-56449417.out',
#  '../results/rivanna/train/project/model_small_lstm_directive_rtx3090_repeat_1/osmi-rtx3090_small_lstm-1-thf2bn-56449410.out',
#  '../results/rivanna/train/project/model_small_lstm_directive_a100_repeat_5/osmi-a100_small_lstm-5-thf2bn-56449371.out',
#  '../results/rivanna/train/project/model_small_lstm_directive_a100_repeat_2/osmi-a100_small_lstm-2-thf2bn-56449368.out',
#  '../results/rivanna/train/project/model_small_lstm_directive_rtx3090_repeat_6/osmi-rtx3090_small_lstm-6-thf2bn-56449415.out',
#  '../results/rivanna/train/project/model_small_lstm_directive_a100-pod_repeat_8/osmi-a100-pod_small_lstm-8-thf2bn-56449427.out']
# 210

# %%
def get(value, df):
    return float(df[df['timer'] == value]["time"])

def get_results(files):
    data = []
    dataframe = pd.DataFrame()

    for filename in files:
        # print (filename)
        content = readfile(filename)
        yaml = os.path.join(os.path.dirname(filename), 'config.yaml')
        config = FlatDict()
        try:
            config.loadf(filename=yaml)
        except Exception as e:
            print (filename)
            print(e)
            print(traceback.format_exc())
            print(f"ERROR: {filename}")
            continue

        lines = Shell.find_lines_with(content, "# csv")
        content = "\n".join(lines)
        
        try:
            df = pd.read_csv(StringIO(content), sep=",")

            df = df.drop(columns=["# csv", "status", "sum", "start", "uname.node", "user",
                                "uname.system", "platform.version", "msg", "tag"])
            for key in ['experiment.model',
                        'experiment.card_name',
                        'constant.nrequests',
                        'experiment.batch',
                        'constant.algorithm',
                        'experiment.concurrency',
                        'experiment.repeat']:
                df[key.split('.')[1]] = config[key]
            df['time'] = df['time'].astype(float)
            df['nrequests'] = df['nrequests'].astype(int)
            df['concurrency'] = df['concurrency'].astype(int)
            df['batch'] = df['batch'].astype(int)
            dataframe = pd.concat([dataframe, df])
        except pd.errors.EmptyDataError as e:
            print(filename)
            print(e)
            print(traceback.format_exc())
            print(f"ERROR: {filename}")
    dataframe['throughput'] = (dataframe['batch']*dataframe['nrequests']) /dataframe['time']
    return dataframe.reset_index().drop(columns=['index'])

dataframe = get_results(files)
# dataframe
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[7], line 59
#      56     dataframe['throughput'] = (dataframe['batch']*dataframe['nrequests']) /dataframe['time']
#      57     return dataframe.reset_index().drop(columns=['index'])
# ---> 59 dataframe = get_results(files)
#      60 # dataframe
#
# Cell In[7], line 31, in get_results(files)
#      28 content = "\n".join(lines)
#      30 try:
# ---> 31     df = pd.read_csv(StringIO(content), sep=",")
#      33     df = df.drop(columns=["# csv", "status", "sum", "start", "uname.node", "user",
#      34                         "uname.system", "platform.version", "msg", "tag"])
#      35     # for exclude in ["init",'number_of_ranks', "number_of_nodes", "version",
#      36     #                 "result", "run_stop", "submission_status"]:
#      37 #         df = df[df['timer'] != exclude]
#
# File ~/ENV3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~/ENV3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py:617, in _read(filepath_or_buffer, kwds)
#     614     return parser
#     616 with parser:
# --> 617     return parser.read(nrows)
#
# File ~/ENV3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1748, in TextFileReader.read(self, nrows)
#    1741 nrows = validate_integer("nrows", nrows)
#    1742 try:
#    1743     # error: "ParserBase" has no attribute "read"
#    1744     (
#    1745         index,
#    1746         columns,
#    1747         col_dict,
# -> 1748     ) = self._engine.read(  # type: ignore[attr-defined]
#    1749         nrows
#    1750     )
#    1751 except Exception:
#    1752     self.close()
#
# File ~/ENV3.12/lib/python3.12/site-packages/pandas/io/parsers/c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File parsers.pyx:843, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File parsers.pyx:904, in pandas._libs.parsers.TextReader._read_rows()
#
# File parsers.pyx:879, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:890, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2058, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 12 fields in line 3, saw 15

# %%
directories = glob("../project-gpu/*")
print(directories)
len(directories)
# Out:
# ['../project-gpu/directive_a100_batch_256_ngpus_1_concurrency_1_model_large_tcnn_repeat_1', '../project-gpu/directive_v100_batch_128_ngpus_1_concurrency_1_model_large_tcnn_repeat_1', '../project-gpu/directive_v100_batch_256_ngpus_1_concurrency_1_model_large_tcnn_repeat_1', '../project-gpu/directive_v100_batch_64_ngpus_1_concurrency_1_model_large_tcnn_repeat_1', '../project-gpu/directive_v100_batch_512_ngpus_1_concurrency_1_model_large_tcnn_repeat_1', '../project-gpu/directive_a100_batch_64_ngpus_1_concurrency_1_model_large_tcnn_repeat_1', '../project-gpu/directive_a100_batch_128_ngpus_1_concurrency_1_model_large_tcnn_repeat_1', '../project-gpu/directive_a100_batch_512_ngpus_1_concurrency_1_model_large_tcnn_repeat_1']
# 8

# %%
def get(value, df):
    df = df[df['name'].str.contains(value)]
    print(len(df))
    return df["time"].astype(float)#.mean()

# %%
def get_results_averaged():
    dataframe = pd.DataFrame()

    for dir in directories:
        yaml = os.path.join(dir, 'config.yaml')
        config = FlatDict()
        config.loadf(filename=yaml)

        result_files = glob(os.path.join(dir, "outputs/log-*.txt"))
        times = []
        for filename in result_files:
            content = readfile(filename)
            lines = Shell.find_lines_with(content, "# csv")
            content = "\n".join(lines)
            if not content:
                print(filename, "has no timers")
                continue
            df = pd.read_csv(StringIO(content), sep=",").reset_index()
            df.rename(columns={'level_1': 'name'}, inplace=True)
            # print(get('loop total', df))
            
            times.append(get('loop total', df))
        time = np.mean(times) if times else np.NaN
        
        
        try:
            df = pd.DataFrame()
            for key in ['experiment.model',
                        'experiment.card_name',
                        'constant.nrequests',
                        'experiment.batch',
                        'constant.algorithm',
                        'experiment.concurrency',
                        'experiment.repeat']:
                df[key.split('.')[1]] = [config[key]]
            df['time'] = time
            df['nrequests'] = df['nrequests'].astype(int)
            df['concurrency'] = df['concurrency'].astype(int)
            df['batch'] = df['batch'].astype(int)
            dataframe = pd.concat([dataframe, df])
        except pd.errors.EmptyDataError as e:
            print(filename)
            print(e)
            print(traceback.format_exc())
            print(f"ERROR: {filename}")
    dataframe['throughput'] = (dataframe['batch']*dataframe['nrequests']) /dataframe['time']
    return dataframe.reset_index().drop(columns=['index'])

# import warnings
# with warnings.catch_warnings():
#     warnings.simplefilter("ignore")
dataframe = get_results_averaged()
dataframe
# Out:
# ../project-gpu/directive_a100_batch_256_ngpus_1_concurrency_1_model_large_tcnn_repeat_1/outputs/log-0-large_tcnn-16384-256-8443.txt has no timers
# 1
# ../project-gpu/directive_v100_batch_256_ngpus_1_concurrency_1_model_large_tcnn_repeat_1/outputs/log-0-large_tcnn-16384-256-8443.txt has no timers
# 1
# ../project-gpu/directive_v100_batch_512_ngpus_1_concurrency_1_model_large_tcnn_repeat_1/outputs/log-0-large_tcnn-16384-512-8443.txt has no timers
# 1
# 1
# ../project-gpu/directive_a100_batch_512_ngpus_1_concurrency_1_model_large_tcnn_repeat_1/outputs/log-0-large_tcnn-16384-512-8443.txt has no timers
#         model card_name  nrequests  batch           algorithm  concurrency  \
# 0  large_tcnn      a100      16384    256  tfs_grpc_client.py            1
# 1  large_tcnn      v100      16384    128  tfs_grpc_client.py            1
# 2  large_tcnn      v100      16384    256  tfs_grpc_client.py            1
# 3  large_tcnn      v100      16384     64  tfs_grpc_client.py            1
# 4  large_tcnn      v100      16384    512  tfs_grpc_client.py            1
# 5  large_tcnn      a100      16384     64  tfs_grpc_client.py            1
# 6  large_tcnn      a100      16384    128  tfs_grpc_client.py            1
# 7  large_tcnn      a100      16384    512  tfs_grpc_client.py            1
#
#   repeat       time  throughput
# 0      1        NaN         NaN
# 1      1  85995.271   24.386829
# 2      1        NaN         NaN
# 3      1  41790.806   25.091069
# 4      1        NaN         NaN
# 5      1  45318.672   23.137836
# 6      1  76299.270   27.485872
# 7      1        NaN         NaN

# %%
dataframe[dataframe['model']=='large_tcnn']['time'].mean()
# Out:
# 62351.00475

# %%
def SAVEFIG(fig, filename, path='./out', formats=('png', 'pdf', "jpg", "tiff")):
    # fileout = f"{local_path}/{filename}".replace("\n", " ").replace(">", " ").replace("<", " ")
    for my_format in formats:
        fig.savefig(f"{path}/{filename}.{my_format}", format=my_format, bbox_inches="tight")
        print (f"writing to {path}/{filename}.{my_format}")
    return fig, tuple(f'{path}/{filename}.{fmt}' for fmt in formats)

# %%
# for c,df in dataframe.groupby('concurrency'):
#     for card, subset in df.groupby('card_name'):
#         plt.figure(figsize=(10,6))
#         plt.plot(subset['batch'], subset['throughput'], marker='o', label=f'Card: {card}')

#     plt.xlabel('Batch')
#     plt.ylabel('Throughput (inf/s)')
#     plt.legend()
#     plt.grid(True)
#     plt.show()

#     SAVEFIG(plt, "throughput_vs_batch")

# %%
for model,model_df in dataframe.groupby('model'):
    for c,df in model_df.groupby('concurrency'):
        plt.clf()
        plt.figure(figsize=(10,6))
        sns.lineplot(data=df, x='batch', y='time', errorbar='sd', hue='card_name', marker='o')
        plt.title(model+': Average Time vs Batch with Error Bars Concurrency ' + str(c))
        plt.xlabel('Batch')
        plt.ylabel('Average Time')
        plt.show()
# Out:
# /home/linuxbrew/.linuxbrew/Cellar/python@3.9/3.9.13_1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/linuxbrew/.linuxbrew/Cellar/python@3.9/3.9.13_1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/linuxbrew/.linuxbrew/Cellar/python@3.9/3.9.13_1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/linuxbrew/.linuxbrew/Cellar/python@3.9/3.9.13_1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/linuxbrew/.linuxbrew/Cellar/python@3.9/3.9.13_1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/linuxbrew/.linuxbrew/Cellar/python@3.9/3.9.13_1/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/linuxbrew/.linuxbrew/Cellar/python@3.9/3.9.13_1/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/linuxbrew/.linuxbrew/Cellar/python@3.9/3.9.13_1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/linuxbrew/.linuxbrew/Cellar/python@3.9/3.9.13_1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/linuxbrew/.linuxbrew/Cellar/python@3.9/3.9.13_1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/linuxbrew/.linuxbrew/Cellar/python@3.9/3.9.13_1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/linuxbrew/.linuxbrew/Cellar/python@3.9/3.9.13_1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/linuxbrew/.linuxbrew/Cellar/python@3.9/3.9.13_1/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/linuxbrew/.linuxbrew/Cellar/python@3.9/3.9.13_1/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/linuxbrew/.linuxbrew/Cellar/python@3.9/3.9.13_1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/linuxbrew/.linuxbrew/Cellar/python@3.9/3.9.13_1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/linuxbrew/.linuxbrew/Cellar/python@3.9/3.9.13_1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/linuxbrew/.linuxbrew/Cellar/python@3.9/3.9.13_1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/linuxbrew/.linuxbrew/Cellar/python@3.9/3.9.13_1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/linuxbrew/.linuxbrew/Cellar/python@3.9/3.9.13_1/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/linuxbrew/.linuxbrew/Cellar/python@3.9/3.9.13_1/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# df = dataframe[dataframe['batch'] == 1]
# print(df)
for model, df in dataframe[dataframe['batch'] == 8].groupby('model'):
    plt.figure(figsize=(10,6))
    sns.lineplot(data=df, x='batch', y='throughput', errorbar='sd', hue='card_name', marker='o')
    plt.title(model+': Throughput vs Concurrency with Error')
    plt.xlabel('Batch')
    plt.ylabel('Throughput')
    plt.show()

# %%
for m, model_df in dataframe.groupby('model'):
        for c, df in model_df.groupby('concurrency'):
                plt.figure(figsize=(12, 6))
                sns.histplot(data=df, x='time', hue='card_name', kde=True, bins=30, palette='viridis')
                plt.title('Histogram of Time '+m+' Concurrency: '+str(c))
                plt.xlabel('Time')
                plt.ylabel('Count')
                plt.show()

# for concurency in [1,2]:
        
#         sns.lineplot(data=df, x='batch', y='time', errorbar='sd', marker='o')

#         plt.title('Average Time vs Batch with Error Bars Concurrency: ' + str(c))
#         plt.xlabel('Batch')
#         plt.ylabel('Average Time')
#         plt.show()
# Out:
# /home/linuxbrew/.linuxbrew/Cellar/python@3.9/3.9.13_1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/linuxbrew/.linuxbrew/Cellar/python@3.9/3.9.13_1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/linuxbrew/.linuxbrew/Cellar/python@3.9/3.9.13_1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/linuxbrew/.linuxbrew/Cellar/python@3.9/3.9.13_1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/linuxbrew/.linuxbrew/Cellar/python@3.9/3.9.13_1/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/linuxbrew/.linuxbrew/Cellar/python@3.9/3.9.13_1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/linuxbrew/.linuxbrew/Cellar/python@3.9/3.9.13_1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/linuxbrew/.linuxbrew/Cellar/python@3.9/3.9.13_1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/linuxbrew/.linuxbrew/Cellar/python@3.9/3.9.13_1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/linuxbrew/.linuxbrew/Cellar/python@3.9/3.9.13_1/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/linuxbrew/.linuxbrew/Cellar/python@3.9/3.9.13_1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/linuxbrew/.linuxbrew/Cellar/python@3.9/3.9.13_1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/linuxbrew/.linuxbrew/Cellar/python@3.9/3.9.13_1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/linuxbrew/.linuxbrew/Cellar/python@3.9/3.9.13_1/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/linuxbrew/.linuxbrew/Cellar/python@3.9/3.9.13_1/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(10,6))

for card in dataframe['card_name'].unique():
    subset = dataframe[dataframe['card_name'] == card]
    plt.plot(subset['batch'], subset['time'], marker='o', label=f'Card: {card}')

plt.xlabel('Batch')
plt.ylabel('Time')
plt.legend()
plt.grid(True)
plt.xticks(dataframe['batch'].unique())  # Ensure all batch numbers are represented on x-axis
plt.show()

# %%
    #     df['jobid'] = job_id

    #     # df = df.drop(rows=["init"])

    #     df['time'] = df['time'].astype(float)
    #     # display(df)
    #     # add mllog entry

    #     # if len(mllog_lines) > 0:
    #     #     print('i see mllog lines')
    #     # else:
    #     #     continue

    #     # print(len(mllog_lines))

    #     # for mllog_line in mllog_lines.splitlines():

    #         # current_dict = eval(mllog_line)
    #         # if current_dict['key'] != 'result':
    #         #     continue

    #         # # if 'key' not in current_dict:
    #         # # pprint(current_dict)

    #         #         # Extracting values
    #         # value = eval(current_dict['value'])

    #         # f = FlatDict(sep='.')
    #         # f.load(value)

    #         # mllog_col_names = ['training.samples', 'training.accuracy', 'training.loss', 'training.val_loss', 'training.val_accuracy', 'training.history.accuracy', 'training.history.loss', 'training.history.val_loss', 'training.history.val_accuracy', 'inference.avg_accuracy', 'inference.accuracy', 'inference_analyze.number', 'inference_analyze.bs', 'inference_analyze.nodes', 'inference_analyze.gpus', 'inference_analyze.time_per_inference']
    #         # mllog_dict = {}
    #         # for key in mllog_col_names:
    #         #     mllog_dict[key] = f[key]
    #         # for key in mllog_dict.keys():
    #         #     df[key] = str(f[key])
    #         # # try:
    #         # # df['train.accuracy'] = value["training"]["history"]["accuracy"]
    #         # # print(train_acc)
    #         # # df['train.loss'] = value["training"]["history"]["loss"]
    #         # # df['val.accuracy'] = value["training"]["history"]["val_accuracy"]
    #         # # df['val.loss'] = value["training"]["history"]["val_loss"]
    #         # # df['test.accuracy'] = value["inference"]["avg_accuracy"]
    #         # # print(mllog_dict)
    #         # # except ValueError:
    #         # #     print('length mismatch.')
    #         # # for key in current_dict.keys():
    #         # #     df[key] = current_dict[key]

    #     total = get("total")
    #     loop_total = get("loop total")
    #     total = get("Total")
    #     client_result = get("client result")
        

    #     #df[["rest"]] = ["rest", 0.0]

    #     # rest = total - training - inference
    #     # rest_row = pd.DataFrame([{'timer':'rest', 'time': rest}])

    #     # df = pd.concat([df, rest_row], ignore_index=True)
    #     # df = pd.concat([rest_row,df.loc[:]]).reset_index(drop=True)

    #     # df[["job"]] = filename.replace(".out","").replace("outputs/", "")
    #     df[["job"]] = os.path.splitext(os.path.basename(filename))[0]
    #     # display(df)

    #     df = df.reset_index()
    #     df = df.drop(columns=["index"])
    #     #display(df)
    #     #print (total, training, inference)
    #     df.reset_index(drop=True, inplace=True)
    #     data.append(df)
    #     # new_dataframe = pd.concat([new_dataframe, df]).reset_index(drop=True)
    #     new_dataframe = pd.concat([new_dataframe,df]).reset_index(drop=True)

# %%
# !ls ../project-gpu/card_name_a100_batch_1_ngpus_1_concurrency_1_model_small_lstm_repeat_1/osmi-1-tma5gv-52955261.out
# Out:
# ls: cannot access '../project-gpu/card_name_a100_batch_1_ngpus_1_concurrency_1_model_small_lstm_repeat_1/osmi-1-tma5gv-52955261.out': No such file or directory

# %%
new_dataframe
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/nkimball/project/osmi/osmi/target/rivanna/analysis/analysis-simple.ipynb Cell 14 line 1
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/nkimball/project/osmi/osmi/target/rivanna/analysis/analysis-simple.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> new_dataframe
#
# NameError: name 'new_dataframe' is not defined

# %%
print(list(new_dataframe.columns))
for key in list(new_dataframe.columns):
    dont_convert = ['timer', 'card_name', 'job']
    convert_to_list = ['training.history.accuracy', 'training.history.loss', 'training.history.val_loss', 'training.history.val_accuracy', 'inference.accuracy']
    convert_to_int = ['repeat', 'training.samples', 'inference_analyze.number', 'inference_analyze.bs', 'inference_analyze.nodes', 'inference_analyze.gpus', 'epoch', 'jobid']


    if key in convert_to_list:
        # new_dataframe[key] = df[key].apply(convert_to_list)
        # df['col1'] = df['col1'].apply(complex_function)
        continue
    elif key in convert_to_int:
        new_dataframe[key] = new_dataframe[key].astype(int)
        continue
    # elif key not in dont_convert:
    #     new_dataframe[key] = new_dataframe[key].astype(float)
    #     continue
    # elif key in dont_convert:
    #     continue

convert_to_float = ['training.accuracy', 'training.loss', 'training.val_loss', 'training.val_accuracy', 'inference.avg_accuracy', 'inference_analyze.time_per_inference']
for column in convert_to_float:
    new_dataframe[column] = new_dataframe[column].astype(float)
for column in convert_to_list:
    new_dataframe[column] = new_dataframe[column].apply(lambda x: ast.literal_eval(x))
# new_dataframe['time'] = new_dataframe['time'].astype(float)
new_dataframe
# Out:
# ['timer', 'time', 'epoch', 'card_name', 'repeat', 'jobid', 'training.samples', 'training.accuracy', 'training.loss', 'training.val_loss', 'training.val_accuracy', 'training.history.accuracy', 'training.history.loss', 'training.history.val_loss', 'training.history.val_accuracy', 'inference.avg_accuracy', 'inference.accuracy', 'inference_analyze.number', 'inference_analyze.bs', 'inference_analyze.nodes', 'inference_analyze.gpus', 'inference_analyze.time_per_inference', 'job']
#                        timer      time  epoch card_name  repeat     jobid  \
# 0                      total  4301.555    100      a100       1  51472126
# 1             training block  4156.877    100      a100       1  51472126
# 2                   training  4156.875    100      a100       1  51472126
# 3                   loaddata     4.857    100      a100       1  51472126
# 4    training_on_mutiple_GPU  4151.475    100      a100       1  51472126
# ..                       ...       ...    ...       ...     ...       ...
# 166  training_on_mutiple_GPU  8922.666     70   rtx2080       1  51472145
# 167          inference block    92.558     70   rtx2080       1  51472145
# 168                inference     0.011     70   rtx2080       1  51472145
# 169               load model     0.249     70   rtx2080       1  51472145
# 170     read inference files     0.007     70   rtx2080       1  51472145
#
#      training.samples  training.accuracy  training.loss  training.val_loss  \
# 0                 970           0.888343       0.252271           0.269165
# 1                 970           0.888343       0.252271           0.269165
# 2                 970           0.888343       0.252271           0.269165
# 3                 970           0.888343       0.252271           0.269165
# 4                 970           0.888343       0.252271           0.269165
# ..                ...                ...            ...                ...
# 166               970           0.885524       0.257720           0.267725
# 167               970           0.885524       0.257720           0.267725
# 168               970           0.885524       0.257720           0.267725
# 169               970           0.885524       0.257720           0.267725
# 170               970           0.885524       0.257720           0.267725
#
#      ...                          training.history.val_loss  \
# 0    ...  [0.40987929701805115, 0.4118395149707794, 0.40...
# 1    ...  [0.40987929701805115, 0.4118395149707794, 0.40...
# 2    ...  [0.40987929701805115, 0.4118395149707794, 0.40...
# 3    ...  [0.40987929701805115, 0.4118395149707794, 0.40...
# 4    ...  [0.40987929701805115, 0.4118395149707794, 0.40...
# ..   ...                                                ...
# 166  ...  [0.410442978143692, 0.39439356327056885, 0.407...
# 167  ...  [0.410442978143692, 0.39439356327056885, 0.407...
# 168  ...  [0.410442978143692, 0.39439356327056885, 0.407...
# 169  ...  [0.410442978143692, 0.39439356327056885, 0.407...
# 170  ...  [0.410442978143692, 0.39439356327056885, 0.407...
#
#                          training.history.val_accuracy inference.avg_accuracy  \
# 0    [0.7581854462623596, 0.7678648233413696, 0.777...               0.885809
# 1    [0.7581854462623596, 0.7678648233413696, 0.777...               0.885809
# 2    [0.7581854462623596, 0.7678648233413696, 0.777...               0.885809
# 3    [0.7581854462623596, 0.7678648233413696, 0.777...               0.885809
# 4    [0.7581854462623596, 0.7678648233413696, 0.777...               0.885809
# ..                                                 ...                    ...
# 166  [0.7685412168502808, 0.7786415815353394, 0.771...               0.884528
# 167  [0.7685412168502808, 0.7786415815353394, 0.771...               0.884528
# 168  [0.7685412168502808, 0.7786415815353394, 0.771...               0.884528
# 169  [0.7685412168502808, 0.7786415815353394, 0.771...               0.884528
# 170  [0.7685412168502808, 0.7786415815353394, 0.771...               0.884528
#
#                                     inference.accuracy  \
# 0    [0.9090511111111111, 0.8642083333333334, 0.917...
# 1    [0.9090511111111111, 0.8642083333333334, 0.917...
# 2    [0.9090511111111111, 0.8642083333333334, 0.917...
# 3    [0.9090511111111111, 0.8642083333333334, 0.917...
# 4    [0.9090511111111111, 0.8642083333333334, 0.917...
# ..                                                 ...
# 166  [0.8976655555555556, 0.8677983333333333, 0.908...
# 167  [0.8976655555555556, 0.8677983333333333, 0.908...
# 168  [0.8976655555555556, 0.8677983333333333, 0.908...
# 169  [0.8976655555555556, 0.8677983333333333, 0.908...
# 170  [0.8976655555555556, 0.8677983333333333, 0.908...
#
#     inference_analyze.number  inference_analyze.bs inference_analyze.nodes  \
# 0                        100                    32                       1
# 1                        100                    32                       1
# 2                        100                    32                       1
# 3                        100                    32                       1
# 4                        100                    32                       1
# ..                       ...                   ...                     ...
# 166                      100                    32                       1
# 167                      100                    32                       1
# 168                      100                    32                       1
# 169                      100                    32                       1
# 170                      100                    32                       1
#
#      inference_analyze.gpus  inference_analyze.time_per_inference  \
# 0                         1                                  1.44
# 1                         1                                  1.44
# 2                         1                                  1.44
# 3                         1                                  1.44
# 4                         1                                  1.44
# ..                      ...                                   ...
# 166                       1                                  0.93
# 167                       1                                  0.93
# 168                       1                                  0.93
# 169                       1                                  0.93
# 170                       1                                  0.93
#
#                                         job
# 0      a100-100-1-cloudmask-thf2bn-51472126
# 1      a100-100-1-cloudmask-thf2bn-51472126
# 2      a100-100-1-cloudmask-thf2bn-51472126
# 3      a100-100-1-cloudmask-thf2bn-51472126
# 4      a100-100-1-cloudmask-thf2bn-51472126
# ..                                      ...
# 166  rtx2080-70-1-cloudmask-thf2bn-51472145
# 167  rtx2080-70-1-cloudmask-thf2bn-51472145
# 168  rtx2080-70-1-cloudmask-thf2bn-51472145
# 169  rtx2080-70-1-cloudmask-thf2bn-51472145
# 170  rtx2080-70-1-cloudmask-thf2bn-51472145
#
# [171 rows x 23 columns]

# %%
def simplify_job(name):
   return " ".join(name.split("-")[:-2]).replace("fox", "dgx")
# display(df)
# df['job_simple'] = df['job'].apply(lambda name: " ".join(name.split("-")[:-2]).replace("fox", "special"))

new_dataframe['job'] = new_dataframe['job'].apply(simplify_job)
new_dataframe
# Out:
#                        timer      time  epoch card_name  repeat     jobid  \
# 0                      total  4301.555    100      a100       1  51472126
# 1             training block  4156.877    100      a100       1  51472126
# 2                   training  4156.875    100      a100       1  51472126
# 3                   loaddata     4.857    100      a100       1  51472126
# 4    training_on_mutiple_GPU  4151.475    100      a100       1  51472126
# ..                       ...       ...    ...       ...     ...       ...
# 166  training_on_mutiple_GPU  8922.666     70   rtx2080       1  51472145
# 167          inference block    92.558     70   rtx2080       1  51472145
# 168                inference     0.011     70   rtx2080       1  51472145
# 169               load model     0.249     70   rtx2080       1  51472145
# 170     read inference files     0.007     70   rtx2080       1  51472145
#
#      training.samples  training.accuracy  training.loss  training.val_loss  \
# 0                 970           0.888343       0.252271           0.269165
# 1                 970           0.888343       0.252271           0.269165
# 2                 970           0.888343       0.252271           0.269165
# 3                 970           0.888343       0.252271           0.269165
# 4                 970           0.888343       0.252271           0.269165
# ..                ...                ...            ...                ...
# 166               970           0.885524       0.257720           0.267725
# 167               970           0.885524       0.257720           0.267725
# 168               970           0.885524       0.257720           0.267725
# 169               970           0.885524       0.257720           0.267725
# 170               970           0.885524       0.257720           0.267725
#
#      ...                          training.history.val_loss  \
# 0    ...  [0.40987929701805115, 0.4118395149707794, 0.40...
# 1    ...  [0.40987929701805115, 0.4118395149707794, 0.40...
# 2    ...  [0.40987929701805115, 0.4118395149707794, 0.40...
# 3    ...  [0.40987929701805115, 0.4118395149707794, 0.40...
# 4    ...  [0.40987929701805115, 0.4118395149707794, 0.40...
# ..   ...                                                ...
# 166  ...  [0.410442978143692, 0.39439356327056885, 0.407...
# 167  ...  [0.410442978143692, 0.39439356327056885, 0.407...
# 168  ...  [0.410442978143692, 0.39439356327056885, 0.407...
# 169  ...  [0.410442978143692, 0.39439356327056885, 0.407...
# 170  ...  [0.410442978143692, 0.39439356327056885, 0.407...
#
#                          training.history.val_accuracy inference.avg_accuracy  \
# 0    [0.7581854462623596, 0.7678648233413696, 0.777...               0.885809
# 1    [0.7581854462623596, 0.7678648233413696, 0.777...               0.885809
# 2    [0.7581854462623596, 0.7678648233413696, 0.777...               0.885809
# 3    [0.7581854462623596, 0.7678648233413696, 0.777...               0.885809
# 4    [0.7581854462623596, 0.7678648233413696, 0.777...               0.885809
# ..                                                 ...                    ...
# 166  [0.7685412168502808, 0.7786415815353394, 0.771...               0.884528
# 167  [0.7685412168502808, 0.7786415815353394, 0.771...               0.884528
# 168  [0.7685412168502808, 0.7786415815353394, 0.771...               0.884528
# 169  [0.7685412168502808, 0.7786415815353394, 0.771...               0.884528
# 170  [0.7685412168502808, 0.7786415815353394, 0.771...               0.884528
#
#                                     inference.accuracy  \
# 0    [0.9090511111111111, 0.8642083333333334, 0.917...
# 1    [0.9090511111111111, 0.8642083333333334, 0.917...
# 2    [0.9090511111111111, 0.8642083333333334, 0.917...
# 3    [0.9090511111111111, 0.8642083333333334, 0.917...
# 4    [0.9090511111111111, 0.8642083333333334, 0.917...
# ..                                                 ...
# 166  [0.8976655555555556, 0.8677983333333333, 0.908...
# 167  [0.8976655555555556, 0.8677983333333333, 0.908...
# 168  [0.8976655555555556, 0.8677983333333333, 0.908...
# 169  [0.8976655555555556, 0.8677983333333333, 0.908...
# 170  [0.8976655555555556, 0.8677983333333333, 0.908...
#
#     inference_analyze.number  inference_analyze.bs inference_analyze.nodes  \
# 0                        100                    32                       1
# 1                        100                    32                       1
# 2                        100                    32                       1
# 3                        100                    32                       1
# 4                        100                    32                       1
# ..                       ...                   ...                     ...
# 166                      100                    32                       1
# 167                      100                    32                       1
# 168                      100                    32                       1
# 169                      100                    32                       1
# 170                      100                    32                       1
#
#      inference_analyze.gpus  inference_analyze.time_per_inference  \
# 0                         1                                  1.44
# 1                         1                                  1.44
# 2                         1                                  1.44
# 3                         1                                  1.44
# 4                         1                                  1.44
# ..                      ...                                   ...
# 166                       1                                  0.93
# 167                       1                                  0.93
# 168                       1                                  0.93
# 169                       1                                  0.93
# 170                       1                                  0.93
#
#                         job
# 0      a100 100 1 cloudmask
# 1      a100 100 1 cloudmask
# 2      a100 100 1 cloudmask
# 3      a100 100 1 cloudmask
# 4      a100 100 1 cloudmask
# ..                      ...
# 166  rtx2080 70 1 cloudmask
# 167  rtx2080 70 1 cloudmask
# 168  rtx2080 70 1 cloudmask
# 169  rtx2080 70 1 cloudmask
# 170  rtx2080 70 1 cloudmask
#
# [171 rows x 23 columns]

# %%
# def get_by_timer(data, timer):
#     d = data[data['timer'] == timer]
#     d = d.reset_index()
#     d["job"] = d["job"].apply(simplify_job)
#     d = d.drop(columns=["index"])
#     return d
#
# total = get_by_timer(data, "total")
#
# total

# %%
cols = list(new_dataframe.columns)
cols.insert(0, cols.pop(cols.index('job')))
new_dataframe = new_dataframe[cols]
print(new_dataframe.columns)
full_df = new_dataframe.copy()
# Out:
# Index(['job', 'timer', 'time', 'epoch', 'card_name', 'repeat', 'jobid',
#        'training.samples', 'training.accuracy', 'training.loss',
#        'training.val_loss', 'training.val_accuracy',
#        'training.history.accuracy', 'training.history.loss',
#        'training.history.val_loss', 'training.history.val_accuracy',
#        'inference.avg_accuracy', 'inference.accuracy',
#        'inference_analyze.number', 'inference_analyze.bs',
#        'inference_analyze.nodes', 'inference_analyze.gpus',
#        'inference_analyze.time_per_inference'],
#       dtype='object')

# %%
def save_image(p, name, dpi=300):
    # Shell.mkdir(directory)
    plt.savefig(f"{name}.svg", bbox_inches="tight")
    plt.savefig(f"{name}.png", bbox_inches="tight", dpi=dpi)
    plt.savefig(f"{name}.pdf", bbox_inches="tight")
    plt.savefig(f"{name}.tiff", bbox_inches="tight")

# %%
# get all the lines from one of the values below
# if we plot all four values
# epoch inferece.accuracy card_name == a100
print(new_dataframe['card_name'].unique())
for gpu in new_dataframe['card_name'].unique():
    plt.clf()
    # Set the figure size
    plt.figure(figsize=(8, 6))  # Adjust the width and height as needed
    subset = new_dataframe.loc[new_dataframe['card_name'] == gpu]
    subset.plot(kind='scatter',
        x='epoch',
        y='inference.avg_accuracy',
        color='red')
# Out:
# ['a100' 'k80' 'p100' 'rtx2080']

# %%
unique_card_names = new_dataframe['card_name'].unique()

# Plotting each card_name separately
for card_name in unique_card_names:
    subset = new_dataframe[new_dataframe['card_name'] == card_name]
    x = subset['epoch']  # Assuming the index represents the epoch number
    y = subset['training.accuracy']
    plt.plot(x, y, label=card_name)

# Set the labels and title
plt.xlabel('Epoch Number')
plt.ylabel('Training Accuracy')
plt.title('Training Accuracy vs. Epoch Number')

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %%
epoch = 100
card_name = 'a100'
repeat = 1
# Plotting each card_name separately
# for card_name in unique_card_names:

def create_accuracy_history_plot(card_name, epoch, repeat):

    subset = new_dataframe[(new_dataframe['card_name'] == card_name) & (new_dataframe['epoch'] == epoch) & (new_dataframe['repeat'] == repeat)]
    # display(subset)
    y = subset['training.history.accuracy'].values[0]  # Extracting the list of accuracy values
    x = range(1, len(y) + 1)  # x-axis represents the index within the list (1-100)
    plt.plot(x, y, label=card_name)

    # Set the labels and title
    plt.xlabel('Index within List')
    plt.ylabel('Training History Accuracy')
    plt.title('Training History Accuracy vs. Index within List (Epoch: Up to {})'.format(epoch))

    # Add a legend
    # plt.legend()

    # Show the plot
    # plt.show()
create_accuracy_history_plot(card_name='a100', epoch=100, repeat=1)
create_accuracy_history_plot(card_name='p100', epoch=70, repeat=1)
create_accuracy_history_plot(card_name='rtx2080', epoch=100, repeat=1)
plt.legend()

Shell.mkdir('./images')
# name = key.replace('.', '-')
save_image(plt, f"./images/training-history")

plt.show()

# %%
card_names = ['a100', 'k80', 'rtx2080']
epochs = [10, 30, 50, 100]
colormap = plt.cm.get_cmap('Set1', len(card_names))

def create_accuracy_history_plot(card_name, epoch):
    subset = new_dataframe[(new_dataframe['card_name'] == card_name) & (new_dataframe['epoch'] == epoch)]

    # Get unique card names
    unique_card_names = subset['card_name'].unique()

    # Plot for each card name
    for card_name in unique_card_names:
        card_subset = subset[subset['card_name'] == card_name]
        x = np.arange(1, len(card_subset['inference.accuracy'].iloc[0]) + 1)
        y = card_subset['inference.accuracy'].iloc[0]
        plt.scatter(x, y, label=epoch)

    plt.xlabel('Index within Sample')
    plt.ylabel('Inference Accuracy')
    plt.title('Inference Accuracy vs. Index within Sample')
    plt.legend()

# for card_name in card_names:
create_accuracy_history_plot('a100', 100)
create_accuracy_history_plot('a100', 70)
# create_accuracy_history_plot('a100', 50)

Shell.mkdir('./images')
# name = key.replace('.', '-')
save_image(plt, f"./images/inference-accuracy")

plt.show()

# %%
card_names = ['a100', 'k80', 'rtx2080']
epochs = [10, 30, 50, 100]
colormap = plt.cm.get_cmap('Set1', len(card_names))

def select_accuracy_history(card_name, epoch):
    subset = new_dataframe[(new_dataframe['card_name'] == card_name) & (new_dataframe['epoch'] == epoch) & (new_dataframe['timer'] == 'total')]
    subset = subset.sort_values(by='inference.accuracy', ascending=True)

    # Get unique card names
    unique_card_names = subset['card_name'].unique()
    return subset

empty = pd.DataFrame()
sb = select_accuracy_history('a100', 100)
sb2 = select_accuracy_history('a100', 70)
empty = pd.concat([sb, sb2], ignore_index=True)
empty = empty.reset_index()
# empty = empty.concat([sb, sb2])

wanted = ['index', 'job', 'epoch', 'card_name', 'inference.accuracy']
drop = [x for x in empty.columns if x not in wanted]
print(drop)

for key in drop:

    empty.drop(key, inplace=True, axis=1)
# for key in list(empty.columns):
#     if str(key) not in :
#         empty.drop(key, inplace=True)

print('heres empty')
display(empty)
# Out:
# ['timer', 'time', 'repeat', 'jobid', 'training.samples', 'training.accuracy', 'training.loss', 'training.val_loss', 'training.val_accuracy', 'training.history.accuracy', 'training.history.loss', 'training.history.val_loss', 'training.history.val_accuracy', 'inference.avg_accuracy', 'inference_analyze.number', 'inference_analyze.bs', 'inference_analyze.nodes', 'inference_analyze.gpus', 'inference_analyze.time_per_inference']
# heres empty
#    index                   job  epoch card_name  \
# 0      0  a100 100 1 cloudmask    100      a100
# 1      1   a100 70 1 cloudmask     70      a100
#
#                                   inference.accuracy
# 0  [0.9090511111111111, 0.8642083333333334, 0.917...
# 1  [0.899965, 0.8610055555555556, 0.9160277777777...

# %%
# Transpose the "inference.accuracy" column values
transposed_100 = empty[empty['epoch'] == 100].explode('inference.accuracy').reset_index(drop=True)
transposed_100.columns = [f"{col}_100" for col in transposed_100.columns]

transposed_70 = empty[empty['epoch'] == 70].explode('inference.accuracy').reset_index(drop=True)
transposed_70.columns = [f"{col}_70" for col in transposed_70.columns]

transposed = pd.concat([transposed_70, transposed_100], axis=1)
transposed.sort_values('inference.accuracy_100', inplace=True, ascending=False)
transposed.drop(['card_name_100', 'card_name_70', 'job_70', 'job_100', 'index_70', 'index_100'], inplace=True, axis=1)

transposed = transposed.rename_axis('index').reset_index()
transposed['good_index'] = transposed.index

transposed
# Out:
#     index  epoch_70 inference.accuracy_70  epoch_100 inference.accuracy_100  \
# 0      75        70              0.963724        100                0.96371
# 1      32        70              0.954737        100               0.957952
# 2      71        70              0.952736        100               0.954155
# 3      48        70              0.951569        100               0.952238
# 4      70        70              0.948237        100                0.94873
# ..    ...       ...                   ...        ...                    ...
# 95     79        70              0.737201        100               0.737034
# 96     58        70              0.723963        100               0.731594
# 97     65        70              0.715878        100               0.724981
# 98     92        70              0.715628        100               0.699426
# 99     90        70              0.589084        100               0.589758
#
#     good_index
# 0            0
# 1            1
# 2            2
# 3            3
# 4            4
# ..         ...
# 95          95
# 96          96
# 97          97
# 98          98
# 99          99
#
# [100 rows x 6 columns]

# %%
# sns.scatterplot(data=transposed, x='index', y='inference_accuracy', hue='card_name_70')
sns.scatterplot(transposed, x='good_index', y='inference.accuracy_70', label='70 Epochs')
sns.scatterplot(transposed, x='good_index', y='inference.accuracy_100', label='100 Epochs')
# transposed.scatter(x='index', y='inference_accuracy_70')
# transposed.scatter(x='index', y='inference_accuracy_100')
# Set the x-axis label
plt.xlabel('Index')
# Set the y-axis label
plt.ylabel('Inference Accuracy')
plt.title('Sorted Inference Accuracy over Sample')
plt.legend()

Shell.mkdir('./images')
# name = key.replace('.', '-')
save_image(plt, f"./images/spectrum-inference-accuracy")

plt.show()

# %%
# create copy
df_copy = new_dataframe #.sort_values('')
wanted = ['index', 'job', 'epoch', 'timer', 'time', 'repeat', 'card_name', 'training.accuracy', 'training.loss', 'training.val_loss', 'training.val_accuracy', 'inference.avg_accuracy']
drop = [x for x in df_copy.columns if x not in wanted]

for key in drop:
    df_copy.drop(key, inplace=True, axis=1)
df_copy
# Out:
# C:\Users\Sledgehammer\AppData\Local\Temp\ipykernel_38028\3549819821.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_copy.drop(key, inplace=True, axis=1)
# C:\Users\Sledgehammer\AppData\Local\Temp\ipykernel_38028\3549819821.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_copy.drop(key, inplace=True, axis=1)
# C:\Users\Sledgehammer\AppData\Local\Temp\ipykernel_38028\3549819821.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_copy.drop(key, inplace=True, axis=1)
# C:\Users\Sledgehammer\AppData\Local\Temp\ipykernel_38028\3549819821.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_copy.drop(key, inplace=True, axis=1)
# C:\Users\Sledgehammer\AppData\Local\Temp\ipykernel_38028\3549819821.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_copy.drop(key, inplace=True, axis=1)
# C:\Users\Sledgehammer\AppData\Local\Temp\ipykernel_38028\3549819821.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_copy.drop(key, inplace=True, axis=1)
# C:\Users\Sledgehammer\AppData\Local\Temp\ipykernel_38028\3549819821.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_copy.drop(key, inplace=True, axis=1)
# C:\Users\Sledgehammer\AppData\Local\Temp\ipykernel_38028\3549819821.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_copy.drop(key, inplace=True, axis=1)
# C:\Users\Sledgehammer\AppData\Local\Temp\ipykernel_38028\3549819821.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_copy.drop(key, inplace=True, axis=1)
# C:\Users\Sledgehammer\AppData\Local\Temp\ipykernel_38028\3549819821.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_copy.drop(key, inplace=True, axis=1)
# C:\Users\Sledgehammer\AppData\Local\Temp\ipykernel_38028\3549819821.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_copy.drop(key, inplace=True, axis=1)
# C:\Users\Sledgehammer\AppData\Local\Temp\ipykernel_38028\3549819821.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_copy.drop(key, inplace=True, axis=1)
#                         job                    timer      time  epoch  \
# 0      a100 100 1 cloudmask                    total  4301.555    100
# 1      a100 100 1 cloudmask           training block  4156.877    100
# 2      a100 100 1 cloudmask                 training  4156.875    100
# 3      a100 100 1 cloudmask                 loaddata     4.857    100
# 4      a100 100 1 cloudmask  training_on_mutiple_GPU  4151.475    100
# ..                      ...                      ...       ...    ...
# 166  rtx2080 70 1 cloudmask  training_on_mutiple_GPU  8922.666     70
# 167  rtx2080 70 1 cloudmask          inference block    92.558     70
# 168  rtx2080 70 1 cloudmask                inference     0.011     70
# 169  rtx2080 70 1 cloudmask               load model     0.249     70
# 170  rtx2080 70 1 cloudmask     read inference files     0.007     70
#
#     card_name  repeat  training.accuracy  training.loss  training.val_loss  \
# 0        a100       1           0.888343       0.252271           0.269165
# 1        a100       1           0.888343       0.252271           0.269165
# 2        a100       1           0.888343       0.252271           0.269165
# 3        a100       1           0.888343       0.252271           0.269165
# 4        a100       1           0.888343       0.252271           0.269165
# ..        ...     ...                ...            ...                ...
# 166   rtx2080       1           0.885524       0.257720           0.267725
# 167   rtx2080       1           0.885524       0.257720           0.267725
# 168   rtx2080       1           0.885524       0.257720           0.267725
# 169   rtx2080       1           0.885524       0.257720           0.267725
# 170   rtx2080       1           0.885524       0.257720           0.267725
#
#      training.val_accuracy  inference.avg_accuracy
# 0                 0.882908                0.885809
# 1                 0.882908                0.885809
# 2                 0.882908                0.885809
# 3                 0.882908                0.885809
# 4                 0.882908                0.885809
# ..                     ...                     ...
# 166               0.886642                0.884528
# 167               0.886642                0.884528
# 168               0.886642                0.884528
# 169               0.886642                0.884528
# 170               0.886642                0.884528
#
# [171 rows x 11 columns]

# %%
df_copy = df_copy.loc[df_copy['timer'] == 'total']
df_copy
# Out:
#                          job  timer       time  epoch card_name  repeat  \
# 0       a100 100 1 cloudmask  total   4301.555    100      a100       1
# 9        a100 10 1 cloudmask  total    728.088     10      a100       1
# 18        a100 2 1 cloudmask  total    647.140      2      a100       1
# 27       a100 30 1 cloudmask  total   1495.592     30      a100       1
# 36       a100 50 1 cloudmask  total   3064.002     50      a100       1
# 45       a100 70 1 cloudmask  total   3102.653     70      a100       1
# 54        k80 10 1 cloudmask  total   7227.690     10       k80       1
# 63         k80 2 1 cloudmask  total   2159.472      2       k80       1
# 72       p100 10 1 cloudmask  total   2642.111     10      p100       1
# 81        p100 2 1 cloudmask  total    973.709      2      p100       1
# 90       p100 30 1 cloudmask  total   8489.737     30      p100       1
# 99       p100 50 1 cloudmask  total  10902.162     50      p100       1
# 108      p100 70 1 cloudmask  total  14695.467     70      p100       1
# 117  rtx2080 100 1 cloudmask  total  12809.693    100   rtx2080       1
# 126   rtx2080 10 1 cloudmask  total   2486.990     10   rtx2080       1
# 135    rtx2080 2 1 cloudmask  total   1012.046      2   rtx2080       1
# 144   rtx2080 30 1 cloudmask  total   6527.227     30   rtx2080       1
# 153   rtx2080 50 1 cloudmask  total  10564.898     50   rtx2080       1
# 162   rtx2080 70 1 cloudmask  total   9021.470     70   rtx2080       1
#
#      training.accuracy  training.loss  training.val_loss  \
# 0             0.888343       0.252271           0.269165
# 9             0.832312       0.343629           0.370266
# 18            0.799343       0.388641           0.402972
# 27            0.872654       0.284226           0.306820
# 36            0.880052       0.271738           0.278948
# 45            0.886616       0.257775           0.276179
# 54            0.823546       0.354994           0.380437
# 63            0.796934       0.392451           0.402417
# 72            0.810620       0.366653           0.394432
# 81            0.802113       0.389560           0.403058
# 90            0.869366       0.288599           0.294026
# 99            0.875247       0.283393           0.305439
# 108           0.882744       0.264044           0.287152
# 117           0.889827       0.248761           0.266637
# 126           0.814853       0.363091           0.379192
# 135           0.798117       0.391228           0.393737
# 144           0.873420       0.282001           0.301372
# 153           0.880296       0.270595           0.291582
# 162           0.885524       0.257720           0.267725
#
#      training.val_accuracy  inference.avg_accuracy
# 0                 0.882908                0.885809
# 9                 0.819647                0.817071
# 18                0.763289                0.808729
# 27                0.866642                0.879109
# 36                0.878290                0.885061
# 45                0.883284                0.884767
# 54                0.821543                0.822653
# 63                0.774141                0.816317
# 72                0.759318                0.807343
# 81                0.760519                0.810091
# 90                0.874427                0.883618
# 99                0.871354                0.874926
# 108               0.875643                0.886373
# 117               0.883383                0.890432
# 126               0.798296                0.804002
# 135               0.783167                0.813717
# 144               0.861411                0.880867
# 153               0.873009                0.884003
# 162               0.886642                0.884528

# %%
parameters = [('training.loss', True),
    ('training.val_loss', True),
    ('training.val_accuracy', False),
    ('inference.avg_accuracy', False)]
# leader = df_copy.sort_values('training.accuracy', ascending=False)
for key, ascending in parameters:

    print('leaderboard', key)
    leader = df_copy.sort_values(key, ascending=ascending)
    display(leader)
# Out:
# leaderboard training.loss
#                          job  timer       time  epoch card_name  repeat  \
# 117  rtx2080 100 1 cloudmask  total  12809.693    100   rtx2080       1
# 0       a100 100 1 cloudmask  total   4301.555    100      a100       1
# 162   rtx2080 70 1 cloudmask  total   9021.470     70   rtx2080       1
# 45       a100 70 1 cloudmask  total   3102.653     70      a100       1
# 108      p100 70 1 cloudmask  total  14695.467     70      p100       1
# 153   rtx2080 50 1 cloudmask  total  10564.898     50   rtx2080       1
# 36       a100 50 1 cloudmask  total   3064.002     50      a100       1
# 144   rtx2080 30 1 cloudmask  total   6527.227     30   rtx2080       1
# 99       p100 50 1 cloudmask  total  10902.162     50      p100       1
# 27       a100 30 1 cloudmask  total   1495.592     30      a100       1
# 90       p100 30 1 cloudmask  total   8489.737     30      p100       1
# 9        a100 10 1 cloudmask  total    728.088     10      a100       1
# 54        k80 10 1 cloudmask  total   7227.690     10       k80       1
# 126   rtx2080 10 1 cloudmask  total   2486.990     10   rtx2080       1
# 72       p100 10 1 cloudmask  total   2642.111     10      p100       1
# 18        a100 2 1 cloudmask  total    647.140      2      a100       1
# 81        p100 2 1 cloudmask  total    973.709      2      p100       1
# 135    rtx2080 2 1 cloudmask  total   1012.046      2   rtx2080       1
# 63         k80 2 1 cloudmask  total   2159.472      2       k80       1
#
#      training.accuracy  training.loss  training.val_loss  \
# 117           0.889827       0.248761           0.266637
# 0             0.888343       0.252271           0.269165
# 162           0.885524       0.257720           0.267725
# 45            0.886616       0.257775           0.276179
# 108           0.882744       0.264044           0.287152
# 153           0.880296       0.270595           0.291582
# 36            0.880052       0.271738           0.278948
# 144           0.873420       0.282001           0.301372
# 99            0.875247       0.283393           0.305439
# 27            0.872654       0.284226           0.306820
# 90            0.869366       0.288599           0.294026
# 9             0.832312       0.343629           0.370266
# 54            0.823546       0.354994           0.380437
# 126           0.814853       0.363091           0.379192
# 72            0.810620       0.366653           0.394432
# 18            0.799343       0.388641           0.402972
# 81            0.802113       0.389560           0.403058
# 135           0.798117       0.391228           0.393737
# 63            0.796934       0.392451           0.402417
#
#      training.val_accuracy  inference.avg_accuracy
# 117               0.883383                0.890432
# 0                 0.882908                0.885809
# 162               0.886642                0.884528
# 45                0.883284                0.884767
# 108               0.875643                0.886373
# 153               0.873009                0.884003
# 36                0.878290                0.885061
# 144               0.861411                0.880867
# 99                0.871354                0.874926
# 27                0.866642                0.879109
# 90                0.874427                0.883618
# 9                 0.819647                0.817071
# 54                0.821543                0.822653
# 126               0.798296                0.804002
# 72                0.759318                0.807343
# 18                0.763289                0.808729
# 81                0.760519                0.810091
# 135               0.783167                0.813717
# 63                0.774141                0.816317
# leaderboard training.val_loss
#                          job  timer       time  epoch card_name  repeat  \
# 117  rtx2080 100 1 cloudmask  total  12809.693    100   rtx2080       1
# 162   rtx2080 70 1 cloudmask  total   9021.470     70   rtx2080       1
# 0       a100 100 1 cloudmask  total   4301.555    100      a100       1
# 45       a100 70 1 cloudmask  total   3102.653     70      a100       1
# 36       a100 50 1 cloudmask  total   3064.002     50      a100       1
# 108      p100 70 1 cloudmask  total  14695.467     70      p100       1
# 153   rtx2080 50 1 cloudmask  total  10564.898     50   rtx2080       1
# 90       p100 30 1 cloudmask  total   8489.737     30      p100       1
# 144   rtx2080 30 1 cloudmask  total   6527.227     30   rtx2080       1
# 99       p100 50 1 cloudmask  total  10902.162     50      p100       1
# 27       a100 30 1 cloudmask  total   1495.592     30      a100       1
# 9        a100 10 1 cloudmask  total    728.088     10      a100       1
# 126   rtx2080 10 1 cloudmask  total   2486.990     10   rtx2080       1
# 54        k80 10 1 cloudmask  total   7227.690     10       k80       1
# 135    rtx2080 2 1 cloudmask  total   1012.046      2   rtx2080       1
# 72       p100 10 1 cloudmask  total   2642.111     10      p100       1
# 63         k80 2 1 cloudmask  total   2159.472      2       k80       1
# 18        a100 2 1 cloudmask  total    647.140      2      a100       1
# 81        p100 2 1 cloudmask  total    973.709      2      p100       1
#
#      training.accuracy  training.loss  training.val_loss  \
# 117           0.889827       0.248761           0.266637
# 162           0.885524       0.257720           0.267725
# 0             0.888343       0.252271           0.269165
# 45            0.886616       0.257775           0.276179
# 36            0.880052       0.271738           0.278948
# 108           0.882744       0.264044           0.287152
# 153           0.880296       0.270595           0.291582
# 90            0.869366       0.288599           0.294026
# 144           0.873420       0.282001           0.301372
# 99            0.875247       0.283393           0.305439
# 27            0.872654       0.284226           0.306820
# 9             0.832312       0.343629           0.370266
# 126           0.814853       0.363091           0.379192
# 54            0.823546       0.354994           0.380437
# 135           0.798117       0.391228           0.393737
# 72            0.810620       0.366653           0.394432
# 63            0.796934       0.392451           0.402417
# 18            0.799343       0.388641           0.402972
# 81            0.802113       0.389560           0.403058
#
#      training.val_accuracy  inference.avg_accuracy
# 117               0.883383                0.890432
# 162               0.886642                0.884528
# 0                 0.882908                0.885809
# 45                0.883284                0.884767
# 36                0.878290                0.885061
# 108               0.875643                0.886373
# 153               0.873009                0.884003
# 90                0.874427                0.883618
# 144               0.861411                0.880867
# 99                0.871354                0.874926
# 27                0.866642                0.879109
# 9                 0.819647                0.817071
# 126               0.798296                0.804002
# 54                0.821543                0.822653
# 135               0.783167                0.813717
# 72                0.759318                0.807343
# 63                0.774141                0.816317
# 18                0.763289                0.808729
# 81                0.760519                0.810091
# leaderboard training.val_accuracy
#                          job  timer       time  epoch card_name  repeat  \
# 162   rtx2080 70 1 cloudmask  total   9021.470     70   rtx2080       1
# 117  rtx2080 100 1 cloudmask  total  12809.693    100   rtx2080       1
# 45       a100 70 1 cloudmask  total   3102.653     70      a100       1
# 0       a100 100 1 cloudmask  total   4301.555    100      a100       1
# 36       a100 50 1 cloudmask  total   3064.002     50      a100       1
# 108      p100 70 1 cloudmask  total  14695.467     70      p100       1
# 90       p100 30 1 cloudmask  total   8489.737     30      p100       1
# 153   rtx2080 50 1 cloudmask  total  10564.898     50   rtx2080       1
# 99       p100 50 1 cloudmask  total  10902.162     50      p100       1
# 27       a100 30 1 cloudmask  total   1495.592     30      a100       1
# 144   rtx2080 30 1 cloudmask  total   6527.227     30   rtx2080       1
# 54        k80 10 1 cloudmask  total   7227.690     10       k80       1
# 9        a100 10 1 cloudmask  total    728.088     10      a100       1
# 126   rtx2080 10 1 cloudmask  total   2486.990     10   rtx2080       1
# 135    rtx2080 2 1 cloudmask  total   1012.046      2   rtx2080       1
# 63         k80 2 1 cloudmask  total   2159.472      2       k80       1
# 18        a100 2 1 cloudmask  total    647.140      2      a100       1
# 81        p100 2 1 cloudmask  total    973.709      2      p100       1
# 72       p100 10 1 cloudmask  total   2642.111     10      p100       1
#
#      training.accuracy  training.loss  training.val_loss  \
# 162           0.885524       0.257720           0.267725
# 117           0.889827       0.248761           0.266637
# 45            0.886616       0.257775           0.276179
# 0             0.888343       0.252271           0.269165
# 36            0.880052       0.271738           0.278948
# 108           0.882744       0.264044           0.287152
# 90            0.869366       0.288599           0.294026
# 153           0.880296       0.270595           0.291582
# 99            0.875247       0.283393           0.305439
# 27            0.872654       0.284226           0.306820
# 144           0.873420       0.282001           0.301372
# 54            0.823546       0.354994           0.380437
# 9             0.832312       0.343629           0.370266
# 126           0.814853       0.363091           0.379192
# 135           0.798117       0.391228           0.393737
# 63            0.796934       0.392451           0.402417
# 18            0.799343       0.388641           0.402972
# 81            0.802113       0.389560           0.403058
# 72            0.810620       0.366653           0.394432
#
#      training.val_accuracy  inference.avg_accuracy
# 162               0.886642                0.884528
# 117               0.883383                0.890432
# 45                0.883284                0.884767
# 0                 0.882908                0.885809
# 36                0.878290                0.885061
# 108               0.875643                0.886373
# 90                0.874427                0.883618
# 153               0.873009                0.884003
# 99                0.871354                0.874926
# 27                0.866642                0.879109
# 144               0.861411                0.880867
# 54                0.821543                0.822653
# 9                 0.819647                0.817071
# 126               0.798296                0.804002
# 135               0.783167                0.813717
# 63                0.774141                0.816317
# 18                0.763289                0.808729
# 81                0.760519                0.810091
# 72                0.759318                0.807343
# leaderboard inference.avg_accuracy
#                          job  timer       time  epoch card_name  repeat  \
# 117  rtx2080 100 1 cloudmask  total  12809.693    100   rtx2080       1
# 108      p100 70 1 cloudmask  total  14695.467     70      p100       1
# 0       a100 100 1 cloudmask  total   4301.555    100      a100       1
# 36       a100 50 1 cloudmask  total   3064.002     50      a100       1
# 45       a100 70 1 cloudmask  total   3102.653     70      a100       1
# 162   rtx2080 70 1 cloudmask  total   9021.470     70   rtx2080       1
# 153   rtx2080 50 1 cloudmask  total  10564.898     50   rtx2080       1
# 90       p100 30 1 cloudmask  total   8489.737     30      p100       1
# 144   rtx2080 30 1 cloudmask  total   6527.227     30   rtx2080       1
# 27       a100 30 1 cloudmask  total   1495.592     30      a100       1
# 99       p100 50 1 cloudmask  total  10902.162     50      p100       1
# 54        k80 10 1 cloudmask  total   7227.690     10       k80       1
# 9        a100 10 1 cloudmask  total    728.088     10      a100       1
# 63         k80 2 1 cloudmask  total   2159.472      2       k80       1
# 135    rtx2080 2 1 cloudmask  total   1012.046      2   rtx2080       1
# 81        p100 2 1 cloudmask  total    973.709      2      p100       1
# 18        a100 2 1 cloudmask  total    647.140      2      a100       1
# 72       p100 10 1 cloudmask  total   2642.111     10      p100       1
# 126   rtx2080 10 1 cloudmask  total   2486.990     10   rtx2080       1
#
#      training.accuracy  training.loss  training.val_loss  \
# 117           0.889827       0.248761           0.266637
# 108           0.882744       0.264044           0.287152
# 0             0.888343       0.252271           0.269165
# 36            0.880052       0.271738           0.278948
# 45            0.886616       0.257775           0.276179
# 162           0.885524       0.257720           0.267725
# 153           0.880296       0.270595           0.291582
# 90            0.869366       0.288599           0.294026
# 144           0.873420       0.282001           0.301372
# 27            0.872654       0.284226           0.306820
# 99            0.875247       0.283393           0.305439
# 54            0.823546       0.354994           0.380437
# 9             0.832312       0.343629           0.370266
# 63            0.796934       0.392451           0.402417
# 135           0.798117       0.391228           0.393737
# 81            0.802113       0.389560           0.403058
# 18            0.799343       0.388641           0.402972
# 72            0.810620       0.366653           0.394432
# 126           0.814853       0.363091           0.379192
#
#      training.val_accuracy  inference.avg_accuracy
# 117               0.883383                0.890432
# 108               0.875643                0.886373
# 0                 0.882908                0.885809
# 36                0.878290                0.885061
# 45                0.883284                0.884767
# 162               0.886642                0.884528
# 153               0.873009                0.884003
# 90                0.874427                0.883618
# 144               0.861411                0.880867
# 27                0.866642                0.879109
# 99                0.871354                0.874926
# 54                0.821543                0.822653
# 9                 0.819647                0.817071
# 63                0.774141                0.816317
# 135               0.783167                0.813717
# 81                0.760519                0.810091
# 18                0.763289                0.808729
# 72                0.759318                0.807343
# 126               0.798296                0.804002

# %%
new_dataframe
# Out:
#                         job                    timer      time  epoch  \
# 0      a100 100 1 cloudmask                    total  4301.555    100
# 1      a100 100 1 cloudmask           training block  4156.877    100
# 2      a100 100 1 cloudmask                 training  4156.875    100
# 3      a100 100 1 cloudmask                 loaddata     4.857    100
# 4      a100 100 1 cloudmask  training_on_mutiple_GPU  4151.475    100
# ..                      ...                      ...       ...    ...
# 166  rtx2080 70 1 cloudmask  training_on_mutiple_GPU  8922.666     70
# 167  rtx2080 70 1 cloudmask          inference block    92.558     70
# 168  rtx2080 70 1 cloudmask                inference     0.011     70
# 169  rtx2080 70 1 cloudmask               load model     0.249     70
# 170  rtx2080 70 1 cloudmask     read inference files     0.007     70
#
#     card_name  repeat  training.accuracy  training.loss  training.val_loss  \
# 0        a100       1           0.888343       0.252271           0.269165
# 1        a100       1           0.888343       0.252271           0.269165
# 2        a100       1           0.888343       0.252271           0.269165
# 3        a100       1           0.888343       0.252271           0.269165
# 4        a100       1           0.888343       0.252271           0.269165
# ..        ...     ...                ...            ...                ...
# 166   rtx2080       1           0.885524       0.257720           0.267725
# 167   rtx2080       1           0.885524       0.257720           0.267725
# 168   rtx2080       1           0.885524       0.257720           0.267725
# 169   rtx2080       1           0.885524       0.257720           0.267725
# 170   rtx2080       1           0.885524       0.257720           0.267725
#
#      training.val_accuracy  inference.avg_accuracy
# 0                 0.882908                0.885809
# 1                 0.882908                0.885809
# 2                 0.882908                0.885809
# 3                 0.882908                0.885809
# 4                 0.882908                0.885809
# ..                     ...                     ...
# 166               0.886642                0.884528
# 167               0.886642                0.884528
# 168               0.886642                0.884528
# 169               0.886642                0.884528
# 170               0.886642                0.884528
#
# [171 rows x 11 columns]

# %%
def create_accuracy_history_plot(card_name, epoch):
    subset = full_df[(full_df['card_name'] == card_name) & (full_df['epoch'] == epoch)]

    subset = subset.sort_values(by='inference.accuracy', ascending=True)
    # Get unique card names
    unique_card_names = subset['card_name'].unique()

    # Plot for each card name
    for card_name in unique_card_names:
        card_subset = subset[subset['card_name'] == card_name]
        x = np.arange(1, len(card_subset['inference.accuracy'].iloc[0]) + 1)
        y = card_subset['inference.accuracy'].iloc[0]
        plt.scatter(x, y, label=epoch)


    plt.xlabel('Index within Sample')
    plt.ylabel('Inference Accuracy')
    plt.title('Inference Accuracy vs. Index within Sample')
    plt.legend()

# for card_name in card_names:
create_accuracy_history_plot('a100', 100)
create_accuracy_history_plot('a100', 70)
# create_accuracy_history_plot('a100', 50)


plt.show()

# %%
# inference analysis.
df_ia = full_df.loc[full_df['card_name'] == 'a100']
df_ia
# Out:
#                      job                    timer      time  epoch card_name  \
# 0   a100 100 1 cloudmask                    total  4301.555    100      a100
# 1   a100 100 1 cloudmask           training block  4156.877    100      a100
# 2   a100 100 1 cloudmask                 training  4156.875    100      a100
# 3   a100 100 1 cloudmask                 loaddata     4.857    100      a100
# 4   a100 100 1 cloudmask  training_on_mutiple_GPU  4151.475    100      a100
# 5   a100 100 1 cloudmask          inference block   143.621    100      a100
# 6   a100 100 1 cloudmask                inference     0.022    100      a100
# 7   a100 100 1 cloudmask               load model     0.214    100      a100
# 8   a100 100 1 cloudmask     read inference files     0.005    100      a100
# 9    a100 10 1 cloudmask                    total   728.088     10      a100
# 10   a100 10 1 cloudmask           training block   587.552     10      a100
# 11   a100 10 1 cloudmask                 training   587.549     10      a100
# 12   a100 10 1 cloudmask                 loaddata     4.584     10      a100
# 13   a100 10 1 cloudmask  training_on_mutiple_GPU   581.444     10      a100
# 14   a100 10 1 cloudmask          inference block   139.502     10      a100
# 15   a100 10 1 cloudmask                inference     0.035     10      a100
# 16   a100 10 1 cloudmask               load model     0.227     10      a100
# 17   a100 10 1 cloudmask     read inference files     0.042     10      a100
# 18    a100 2 1 cloudmask                    total   647.140      2      a100
# 19    a100 2 1 cloudmask           training block   504.595      2      a100
# 20    a100 2 1 cloudmask                 training   504.591      2      a100
# 21    a100 2 1 cloudmask                 loaddata     3.360      2      a100
# 22    a100 2 1 cloudmask  training_on_mutiple_GPU   499.562      2      a100
# 23    a100 2 1 cloudmask          inference block   142.337      2      a100
# 24    a100 2 1 cloudmask                inference     0.037      2      a100
# 25    a100 2 1 cloudmask               load model     0.248      2      a100
# 26    a100 2 1 cloudmask     read inference files     0.002      2      a100
# 27   a100 30 1 cloudmask                    total  1495.592     30      a100
# 28   a100 30 1 cloudmask           training block  1372.997     30      a100
# 29   a100 30 1 cloudmask                 training  1372.994     30      a100
# 30   a100 30 1 cloudmask                 loaddata     4.519     30      a100
# 31   a100 30 1 cloudmask  training_on_mutiple_GPU  1367.790     30      a100
# 32   a100 30 1 cloudmask          inference block   121.583     30      a100
# 33   a100 30 1 cloudmask                inference     0.030     30      a100
# 34   a100 30 1 cloudmask               load model     0.212     30      a100
# 35   a100 30 1 cloudmask     read inference files     0.003     30      a100
# 36   a100 50 1 cloudmask                    total  3064.002     50      a100
# 37   a100 50 1 cloudmask           training block  2860.232     50      a100
# 38   a100 50 1 cloudmask                 training  2860.230     50      a100
# 39   a100 50 1 cloudmask                 loaddata     3.827     50      a100
# 40   a100 50 1 cloudmask  training_on_mutiple_GPU  2855.860     50      a100
# 41   a100 50 1 cloudmask          inference block   202.301     50      a100
# 42   a100 50 1 cloudmask                inference     0.043     50      a100
# 43   a100 50 1 cloudmask               load model     0.249     50      a100
# 44   a100 50 1 cloudmask     read inference files     0.048     50      a100
# 45   a100 70 1 cloudmask                    total  3102.653     70      a100
# 46   a100 70 1 cloudmask           training block  2949.972     70      a100
# 34  [0.8856444444444445, 0.8686366666666666, 0.896...
# 35  [0.8856444444444445, 0.8686366666666666, 0.896...
# 36  [0.9062427777777777, 0.8596, 0.913862222222222...
# 37  [0.9062427777777777, 0.8596, 0.913862222222222...
# 38  [0.9062427777777777, 0.8596, 0.913862222222222...
# 39  [0.9062427777777777, 0.8596, 0.913862222222222...
# 40  [0.9062427777777777, 0.8596, 0.913862222222222...
# 41  [0.9062427777777777, 0.8596, 0.913862222222222...
# 42  [0.9062427777777777, 0.8596, 0.913862222222222...
# 43  [0.9062427777777777, 0.8596, 0.913862222222222...
# 44  [0.9062427777777777, 0.8596, 0.913862222222222...
# 45  [0.899965, 0.8610055555555556, 0.9160277777777...
# 46  [0.899965, 0.8610055555555556, 0.9160277777777...
# 47  [0.899965, 0.8610055555555556, 0.9160277777777...
# 48  [0.899965, 0.8610055555555556, 0.9160277777777...
# 49  [0.899965, 0.8610055555555556, 0.9160277777777...
# 50  [0.899965, 0.8610055555555556, 0.9160277777777...
# 51  [0.899965, 0.8610055555555556, 0.9160277777777...
# 52  [0.899965, 0.8610055555555556, 0.9160277777777...
# 53  [0.899965, 0.8610055555555556, 0.9160277777777...
#
#    inference_analyze.number  inference_analyze.bs inference_analyze.nodes  \
# 0                       100                    32                       1
# 1                       100                    32                       1
# 2                       100                    32                       1
# 3                       100                    32                       1
# 4                       100                    32                       1
# 5                       100                    32                       1
# 6                       100                    32                       1
# 7                       100                    32                       1
# 8                       100                    32                       1
# 9                       100                    32                       1
# 10                      100                    32                       1
# 11                      100                    32                       1
# 12                      100                    32                       1
# 13                      100                    32                       1
# 14                      100                    32                       1
# 15                      100                    32                       1
# 16                      100                    32                       1
# 17                      100                    32                       1
# 18                      100                    32                       1
# 19                      100                    32                       1
# 20                      100                    32                       1
# 21                      100                    32                       1
# 22                      100                    32                       1
# 23                      100                    32                       1
# 24                      100                    32                       1
# 25                      100                    32                       1
# 26                      100                    32                       1
# 27                      100                    32                       1
# 28                      100                    32                       1
# 29                      100                    32                       1
# 30                      100                    32                       1
# 31                      100                    32                       1
# 32                      100                    32                       1
# 33                      100                    32                       1
# 34                      100                    32                       1
# 35                      100                    32                       1
# 36                      100                    32                       1
# 37                      100                    32                       1
# 38                      100                    32                       1
# 39                      100                    32                       1
# 40                      100                    32                       1
# 41                      100                    32                       1
# 42                      100                    32                       1
# 43                      100                    32                       1
# 44                      100                    32                       1
# 45                      100                    32                       1
# 46                      100                    32                       1
# 47                      100                    32                       1
# 48                      100                    32                       1
# 49                      100                    32                       1
# 50                      100                    32                       1
# 51                      100                    32                       1
# 52                      100                    32                       1
# 53                      100                    32                       1
#
#     inference_analyze.gpus  inference_analyze.time_per_inference
# 0                        1                                  1.44
# 1                        1                                  1.44
# 2                        1                                  1.44
# 3                        1                                  1.44
# 4                        1                                  1.44
# 5                        1                                  1.44
# 6                        1                                  1.44
# 7                        1                                  1.44
# 8                        1                                  1.44
# 9                        1                                  1.40
# 10                       1                                  1.40
# 11                       1                                  1.40
# 12                       1                                  1.40
# 13                       1                                  1.40
# 14                       1                                  1.40
# 15                       1                                  1.40
# 16                       1                                  1.40
# 17                       1                                  1.40
# 18                       1                                  1.42
# 19                       1                                  1.42
# 20                       1                                  1.42
# 21                       1                                  1.42
# 22                       1                                  1.42
# 23                       1                                  1.42
# 24                       1                                  1.42
# 25                       1                                  1.42
# 26                       1                                  1.42
# 27                       1                                  1.22
# 28                       1                                  1.22
# 29                       1                                  1.22
# 30                       1                                  1.22
# 31                       1                                  1.22
# 32                       1                                  1.22
# 33                       1                                  1.22
# 34                       1                                  1.22
# 35                       1                                  1.22
# 36                       1                                  2.02
# 37                       1                                  2.02
# 38                       1                                  2.02
# 39                       1                                  2.02
# 40                       1                                  2.02
# 41                       1                                  2.02
# 42                       1                                  2.02
# 43                       1                                  2.02
# 44                       1                                  2.02
# 45                       1                                  1.50
# 46                       1                                  1.50
# 47                       1                                  1.50
# 48                       1                                  1.50
# 49                       1                                  1.50
# 50                       1                                  1.50
# 51                       1                                  1.50
# 52                       1                                  1.50
# 53                       1                                  1.50
#
# [54 rows x 23 columns]

# %%
epoch = 100
card_name = 'a100'
repeat = 1
# Plotting each card_name separately
# for card_name in unique_card_names:

def create_history_plot(card_name, epoch, repeat, key):

    subset = full_df[(full_df['card_name'] == card_name) & (full_df['epoch'] == epoch) & (full_df['repeat'] == repeat)]
    # display(subset)
    y = subset[key].values[0]  # Extracting the list of accuracy values
    x = range(1, len(y) + 1)  # x-axis represents the index within the list (1-100)
    plt.plot(x, y, label=card_name.upper())

    # Set the labels and title
    plt.xlabel('Epoch')
    plt.ylabel(key.title().replace('.', ' ').replace('_', ' '))
    plt.title(f'{key.title().replace(".", " ").replace("_", " ")} vs. Epoch: Up to 100')

    # Add a legend
    # plt.legend()

    # Show the plot
    # plt.show()

# %%
create_history_plot(card_name='a100', epoch=100, repeat=1, key='training.history.loss')
create_history_plot(card_name='a100', epoch=100, repeat=1, key='training.history.accuracy')
# create_history_plot(card_name='rtx2080', epoch=100, repeat=1)
plt.legend()
plt.show()

# %%
create_history_plot(card_name='rtx2080', epoch=100, repeat=1, key='training.history.accuracy')
create_history_plot(card_name='a100', epoch=100, repeat=1, key='training.history.accuracy')
create_history_plot(card_name='k80', epoch=10, repeat=1, key='training.history.accuracy')
create_history_plot(card_name='p100', epoch=70, repeat=1, key='training.history.accuracy')
# create_history_plot(card_name='rtx2080', epoch=100, repeat=1)
plt.legend()

Shell.mkdir('./images')
# name = key.replace('.', '-')
save_image(plt, f"./images/training-history-all-cards")

plt.show()

# %%
create_history_plot(card_name='rtx2080', epoch=100, repeat=1, key='training.history.loss')
create_history_plot(card_name='a100', epoch=100, repeat=1, key='training.history.loss')
create_history_plot(card_name='k80', epoch=10, repeat=1, key='training.history.loss')
create_history_plot(card_name='p100', epoch=70, repeat=1, key='training.history.loss')
# create_history_plot(card_name='rtx2080', epoch=100, repeat=1)
plt.legend()

Shell.mkdir('./images')
# name = key.replace('.', '-')
save_image(plt, f"./images/training-history-loss-all-cards")

plt.show()

# %%
for key in ['training.history.loss', 'training.history.accuracy', 'training.history.val_loss', 'training.history.val_accuracy']:

    create_history_plot(card_name='rtx2080', epoch=100, repeat=1, key=key)
    create_history_plot(card_name='a100', epoch=100, repeat=1, key=key)
    create_history_plot(card_name='k80', epoch=10, repeat=1, key=key)
    create_history_plot(card_name='p100', epoch=70, repeat=1, key=key)
    # create_history_plot(card_name='rtx2080', epoch=100, repeat=1)

    plt.legend()

    Shell.mkdir('./images')
    name = key.replace('.', '-')
    save_image(plt, f"./images/{name}")

    plt.show()

# %%
df['training.history.loss']
df['training.history.accuracy']
df['training.history.val_loss']
df['training.history.val_accuracy']
df['inference.accuracy']
# Out:
# 0    [0.8976655555555556, 0.8677983333333333, 0.908...
# 1    [0.8976655555555556, 0.8677983333333333, 0.908...
# 2    [0.8976655555555556, 0.8677983333333333, 0.908...
# 3    [0.8976655555555556, 0.8677983333333333, 0.908...
# 4    [0.8976655555555556, 0.8677983333333333, 0.908...
# 5    [0.8976655555555556, 0.8677983333333333, 0.908...
# 6    [0.8976655555555556, 0.8677983333333333, 0.908...
# 7    [0.8976655555555556, 0.8677983333333333, 0.908...
# 8    [0.8976655555555556, 0.8677983333333333, 0.908...
# Name: inference.accuracy, dtype: object

# %%
"""
+-------------------------+----------+---------+
| Name                    | Status   |    Time |
|-------------------------+----------+---------+
| total                   | ok       | 203.461 |
| init                    | ok       |   0     |
| number_of_ranks         | ok       |   0     |
| number_of_nodes         | ok       |   0     |
| version                 | ok       |   0     |
| training block          | ok       | 152.313 |
| training                | ok       | 152.299 |
| loaddata                | ok       |   1.766 |
| training_on_mutiple_GPU | ok       | 148.641 |
| inference block         | ok       |  51.018 |
| inference               | ok       |   0.006 |
| load model              | ok       |   0.196 |
| read inference files    | ok       |   0.009 |
| result                  | ok       |   0     |
| run_stop                | ok       |   0     |
| submission_status       | ok       |   0     |
+-------------------------+----------+---------+
"""

addons = pd.DataFrame(
    [
        {'timer':'total', 'time': 203.461, 'job': 'rtx3090 desktop'},
        {'timer':'total', 'time': 660.296, 'job': 'a100 greene'}
    ])
total = pd.concat([total, addons], ignore_index=True)


total
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [433], line 29
#       1 """
#       2 +-------------------------+----------+---------+
#       3 | Name                    | Status   |    Time |
#    (...)
#      21 +-------------------------+----------+---------+
#      22 """
#      24 addons = pd.DataFrame(
#      25     [
#      26         {'timer':'total', 'time': 203.461, 'job': 'rtx3090 desktop'},
#      27         {'timer':'total', 'time': 660.296, 'job': 'a100 greene'}
#      28     ])
# ---> 29 total = pd.concat([total, addons], ignore_index=True)
#      32 total
#
# File ~\ENV3\lib\site-packages\pandas\util\_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File ~\ENV3\lib\site-packages\pandas\core\reshape\concat.py:369, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     147 @deprecate_nonkeyword_arguments(version=None, allowed_args=["objs"])
#     148 def concat(
#     149     objs: Iterable[NDFrame] | Mapping[HashableT, NDFrame],
#    (...)
#     158     copy: bool = True,
#     159 ) -> DataFrame | Series:
#     160     """
#     161     Concatenate pandas objects along a particular axis.
#     162
#    (...)
#     367     1   3   4
#     368     """
# --> 369     op = _Concatenator(
#     370         objs,
#     371         axis=axis,
#     372         ignore_index=ignore_index,
#     373         join=join,
#     374         keys=keys,
#     375         levels=levels,
#     376         names=names,
#     377         verify_integrity=verify_integrity,
#     378         copy=copy,
#     379         sort=sort,
#     380     )
#     382     return op.get_result()
#
# File ~\ENV3\lib\site-packages\pandas\core\reshape\concat.py:459, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     454     if not isinstance(obj, (ABCSeries, ABCDataFrame)):
#     455         msg = (
#     456             f"cannot concatenate object of type '{type(obj)}'; "
#     457             "only Series and DataFrame objs are valid"
#     458         )
# --> 459         raise TypeError(msg)
#     461     ndims.add(obj.ndim)
#     463 # get the sample
#     464 # want the highest ndim that we have, and must be non-empty
#     465 # unless all objs are empty
#
# TypeError: cannot concatenate object of type '<class 'float'>'; only Series and DataFrame objs are valid

# %%
total = total.sort_values(by=['time'], ascending=False)

# %%
def save_image(p, name, dpi=300):
    # Shell.mkdir(directory)
    p.figure.savefig(f"{name}.svg", bbox_inches="tight")
    p.figure.savefig(f"{name}.png", bbox_inches="tight", dpi=dpi)
    p.figure.savefig(f"{name}.pdf", bbox_inches="tight")
    p.figure.savefig(f"{name}.tiff", bbox_inches="tight")

# %%
total

# %%
def plot_by_timer(data, timer):
    plt.xticks(rotation=45)
    p = sns.barplot(data, x="job", y="time")
    p.set(xlabel = "GPU", ylabel = "Time in s")
    p.set_title(f"{timer} Runtime Comparision of Rivanna GPUs")
    return p

p = plot_by_timer(total, "total")

# %%
if not os.path.isdir('./images'):
    Shell.mkdir('./images')
save_image(p, "./images/comparision-epoch-1", dpi=300)

# %%
training = get_by_timer(data, "training block")
plot_by_timer(training, "training block")

training

# %%
inference = get_by_timer(data, "inference block")
plot_by_timer(inference, "inference block")

inference

# %%
_data = data[data['timer'].isin(["total","training block","inference block"])]
_data = _data.sort_values(by=['time'], ascending=False)
_data = _data.reset_index()
_data["job"] = _data["job"].apply(simplify_job)
_data = _data.drop(columns=["index"])

# _data["job"] = _data["job"].apply(simplify_job)
# _data = _data.drop(columns=["index"])

_data

# %%
def get(name):
    content = data[data.timer.isin([name])]['time'].tolist()
    return {name: content}


#plt.xticks(rotation=45)
#p.set(xlabel = "GPU", ylabel = "Time in s")
#p.set_title("Runtime Comparision of Rivanna GPUs")


stacked = pd.DataFrame(
    get('job'), get('total'), get('training block')
)

stacked

stacked.set_index('job').plot(kind='bar', stacked=True, color=['blue', 'red', 'orange'])

# %%
# Import statements
from cloudmesh.common.util import readfile
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt


import sys
import os

# %%
try:
    Shell.rm('megalode.log')
except:
    pass
try:
    Shell.run(f'cat {dirname} * >> megalode.log')
except Exception as e:
    print(e.output)

# %%
mlperf_file = 'megalode.log'
# Read file
content = readfile(mlperf_file).splitlines()

# Create dataframes
train_df = pd.DataFrame(columns = ['Run','Epochs','Train Accuracy','Train Loss','Validation Accuracy','Validation Loss'])
test_df = pd.DataFrame(columns = ['Epochs', 'Test Accuracy'])

run = 0
# Appending accuracies to the dataframe
for line in content:
    # Locate Result line
    if ':::MLLOG' in line and '"key": "result"' in line and 'training' in line:
        # String to a dict using json.loads
        # print(line)
        d = json.loads(line.split(":::MLLOG ")[1])

        # Extracting values
        train_acc = eval(d["value"])["training"]["history"]["accuracy"]
        # print(train_acc)
        train_loss = eval(d["value"])["training"]["history"]["loss"]
        val_acc = eval(d["value"])["training"]["history"]["val_accuracy"]
        val_loss = eval(d["value"])["training"]["history"]["val_loss"]
        test_acc = eval(d["value"])["inference"]["avg_accuracy"]

        # Checking length of the lists
        epochs = len(train_acc)
        if epochs == len(train_loss) and epochs == len(val_acc) and epochs == len(val_loss):

            # Appending to dataframe
            for i in range(epochs):

                train_df.loc[len(train_df.index)] = ["Run " + str(run+1), i + 1, train_acc[i], train_loss[i], val_acc[i], val_loss[i]]
            test_df.loc[len(test_df.index)] = [epochs, test_acc]
        else:
            print("The values for accuracies and losses don't have same length.")
            raise ValueError

        run+=1

# print(train_df)
# print(test_df)

# Creating images directory
if not os.path.exists("images"):
    os.makedirs("images")
train_df

# %%
# Plotting the graphs
acc_plot = sns.lineplot(data = train_df , x = "Epochs", y = "Train Accuracy", label = "Train Accuracy")
acc_plot = sns.lineplot(data = train_df , x = "Epochs", y = "Validation Accuracy", label = "Validation Accuracy")
acc_plot = sns.lineplot(data = test_df , x = "Epochs" , y = "Test Accuracy", label = "Test Accuracy")
acc_plot.set(xlabel = "Epochs", ylabel = "Accuracies")
acc_plot.set_title("Epochs vs. Accuracies")

# %%
# Saving figure in different formats
acc_plot.figure.savefig("images/epoch_vs_accuracy.svg")
acc_plot.figure.savefig("images/epoch_vs_accuracy.png", dpi=300)
acc_plot.figure.savefig("images/epoch_vs_accuracy.pdf")

# Clearing the figure
acc_plot.figure.clf()

loss_plot = sns.lineplot(data = train_df , x = "Epochs", y = "Train Loss", label = "Train Loss")
loss_plot = sns.lineplot(data = train_df , x = "Epochs", y = "Validation Loss", label = "Validation Loss")
loss_plot.set(xlabel = "Epochs", ylabel = "Losses")
loss_plot.set_title("Epochs vs. Losses")

loss_plot.figure.savefig("images/epoch_vs_loss.svg")
loss_plot.figure.savefig("images/epoch_vs_loss.png", dpi = 300)
loss_plot.figure.savefig("images/epoch_vs_loss.pdf")

loss_plot.figure.clf()

# Plotting different runs seperately
if(run>1):
    sns.color_palette("pastel")
    train_acc_plot = sns.lineplot(data = train_df, y = "Train Accuracy", x = "Epochs", hue = "Run", palette="pastel")
    train_acc_plot.set_title("Train Accuracies for different runs")
    train_acc_plot.set(xlabel = "Epochs", ylabel = "Train Accuracy")

    train_acc_plot.figure.savefig("images/train_accuracy_diff_runs.svg")
    train_acc_plot.figure.savefig("images/train_accuracy_diff_runs.png", dpi=300)
    train_acc_plot.figure.savefig("images/train_accuracy_diff_runs.pdf")

    train_acc_plot.figure.clf()

    train_loss_plot = sns.lineplot(data = train_df, y = "Train Loss", x = "Epochs", hue = "Run", palette="pastel")
    train_loss_plot.set_title("Train Losses for different runs")
    train_loss_plot.set(xlabel = "Epochs", ylabel = "Train Loss")

    train_loss_plot.figure.savefig("images/train_loss_diff_runs.svg")
    train_loss_plot.figure.savefig("images/train_loss_diff_runs.png", dpi=300)
    train_loss_plot.figure.savefig("images/train_loss_diff_runs.pdf")

    train_loss_plot.figure.clf()


    val_acc_plot = sns.lineplot(data = train_df, y = "Validation Accuracy", x = "Epochs", hue = "Run", palette="pastel")
    val_acc_plot.set_title("Validation Accuracies for different runs")
    val_acc_plot.set(xlabel = "Epochs", ylabel = "Validation Accuracy")

    val_acc_plot.figure.savefig("images/validation_accuracy_diff_runs.svg")
    val_acc_plot.figure.savefig("images/validation_accuracy_diff_runs.png", dpi=300)
    val_acc_plot.figure.savefig("images/validation_accuracy_diff_runs.pdf")

    val_acc_plot.figure.clf()

    val_loss_plot = sns.lineplot(data = train_df, y = "Validation Loss", x = "Epochs", hue = "Run", palette="pastel")
    val_loss_plot.set_title("Validation Losses for different runs")
    val_loss_plot.set(xlabel = "Epochs", ylabel = "Validation Loss")

    val_loss_plot.figure.savefig("images/validation_loss_diff_runs.svg")
    val_loss_plot.figure.savefig("images/validation_loss_diff_runs.png", dpi=300)
    val_loss_plot.figure.savefig("images/validation_loss_diff_runs.pdf")

    val_loss_plot.figure.clf()

# %%
def epoch_vs_perf(cloudmask_file):

    # Create lists
    time_for_training = []
    time_for_inference = []
    epochs = []

    # Read contents in the file
    content = readfile(cloudmask_file).splitlines()
    for line in content:
        split_line = line.split(",")
        for vals in split_line:
            if "CloudMask training" in split_line and 'time_per' in vals.strip():
                time_for_training.append(float(vals.split("=")[1]))
            elif "CloudMask inference" in split_line and 'time_per' in vals.strip():
                time_for_inference.append(float(vals.split("=")[1]))

            if "epochs" in vals.strip():
                epochs.append(int(vals.split("=")[1]))

    if len(epochs) == len(time_for_training) and len(epochs) == len(time_for_inference):
        # Construct dataframe
        train_time =  pd.DataFrame(columns = ['Epochs','Average Time Per Epoch (ms)'])
        test_time =  pd.DataFrame(columns = ['Epochs','Average Time Per Epoch (ms)'])

        # Appending values to dataframe
        #print(time_for_training)
        #print(time_for_inference)
        #print(epochs)
        for i in range(len(epochs)):
            train_time.loc[len(train_time.index)] = [epochs[i], time_for_training[i]]
            test_time.loc[len(test_time.index)] = [epochs[i], time_for_inference[i]]

        # Plotting the graphs
        train_time_plot = sns.lineplot(data = train_time , y = "Epochs", x = "Average Time Per Epoch (ms)", label = "Train Avg. time per epoch")
        train_time_plot.set(xlabel = "Epochs", ylabel = "Average Time Per Epoch (ms)")
        train_time_plot.set_title("Epochs vs. Avg. time per epoch")

        train_time_plot.figure.savefig("images/epoch_vs_train_time.svg")
        train_time_plot.figure.savefig("images/epoch_vs_train_time.png", dpi = 300)
        train_time_plot.figure.savefig("images/epoch_vs_train_time.pdf")

        train_time_plot.figure.clf()

        test_time_plot = sns.lineplot(data = test_time , y = "Epochs", x = "Average Time Per Epoch (ms)", label = "Inference Avg. Time per epoch")
        test_time_plot.set(xlabel = "Epochs", ylabel = "Average Time Per Epoch (ms)")
        test_time_plot.set_title("Epochs vs. Avg. time per epoch")

        test_time_plot.figure.savefig("images/epoch_vs_test_time.svg")
        test_time_plot.figure.savefig("images/epoch_vs_test_time.png", dpi = 300)
        test_time_plot.figure.savefig("images/epoch_vs_test_time.pdf")

        test_time_plot.figure.clf()

    else:
        print("The Cloudmask file has extra unsuccessful attempt values.")
        return
